# %%
import numpy as np

def StandardScaler(data):
  print ((data - np.mean(data)) / np.std(data))

data = np.array([[5, 0],[1, 5],[5, 1],[5, 5]])
StandardScaler(data)
# Out:
# [[ 0.76736574 -1.59375961]
#  [-1.12153454  0.76736574]
#  [ 0.76736574 -1.12153454]
#  [ 0.76736574  0.76736574]]
